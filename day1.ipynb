# %% [markdown]
# <a href="https://colab.research.google.com/github/YaashxMishra/aws-python/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('yash')
# Out:
# yash

# %%
# variable
a='hello'
print(a)
print(id(a))

b="hello"
print(b)
print(id(b))
# Out:
# hello
# 132995752571216
# hello
# 132995752571216
